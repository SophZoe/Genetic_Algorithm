# %%
#!pip install pandas
import pandas as pd
import os

# %%
cwd = os.getcwd() + "/results_worlds/"
filename = "0___World(1).csv"

df = pd.read_csv(cwd + filename)

intl = df[df["Intelligent"] == True]   # nur intelligente
aggr = df[df["Aggressive"] == True]    # nur aggressive

# %%
#df.describe()

intl
# Out:
#     agent_number  reproduction_counter  consume_counter  sickness_counter  \
# 0              5                     0               16                 0
# 3             15                     4                5                 0
# 4             17                     0               15                 0
# 5             18                     0                6                 0
# 8             21                     0                6                 0
# 9             22                     0                8                 0
# 10            23                     0                8                 0
# 12            25                     0                8                 0
# 13            26                     0                6                 0
# 15            28                     0                5                 0
# 17            30                     0                5                 0
# 18            31                     0                7                 0
# ...
