# %%
#!pip install pandas
import pandas as pd
import os

# %%
cwd = os.getcwd() + "/results_worlds/"
filename = "0___World(1).csv"

df = pd.read_csv(cwd + filename)

# %%
df.describe()
# Out:
#        agent_number  reproduction_counter  consume_counter  sickness_counter  \
# count     12.000000             12.000000        12.000000              12.0
# mean       8.166667              0.666667         1.416667               0.0
# std        4.152400              1.073087         0.792961               0.0
# min        1.000000              0.000000         0.000000               0.0
# 25%        5.750000              0.000000         1.000000               0.0
# 50%        8.500000              0.000000         1.000000               0.0
# 75%       11.250000              1.250000         2.000000               0.0
# max       14.000000              3.000000         3.000000               0.0
#
#        covered_distance   expelled  parent_A  parent_B  Condition  \
# count         12.000000  12.000000  9.000000  9.000000  12.000000
# mean          12.083333   1.500000  3.111111  3.666667   0.666667
# std           13.667868   4.889692  1.691482  1.414214   0.887625
# ...
